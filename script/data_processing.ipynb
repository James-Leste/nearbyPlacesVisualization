# %%
import pandas as pd
import csv
import json

# %%
split = [4, 6]
combinedPlaces = []

for x in range(0, split[0]):
    for y in range(0, split[1]):
        data = pd.read_json(f'../results/{x}-{y}.json')
        if('places' in data):
            combinedPlaces.extend(data["places"])
        else:
            continue

combinedJson = {'places': combinedPlaces}
len(combinedJson["places"])
# Out:
# 327

# %%
def extract_postal_code(address_components):
    for component in address_components:
        if "postal_code" in component["types"]:
            
            return component["longText"]
    return None

# %%
csv_data = []
for idx, place in enumerate(combinedJson['places']):
    name = place['name']
    display_name = place['displayName']['text']
    postal_code = extract_postal_code(place['addressComponents'])
    
    google_maps_uri = place['googleMapsUri']
    
    csv_data.append([idx, name, display_name, postal_code, google_maps_uri])

csv_header = ['Index', 'Name', 'DisplayName', 'PostalCode', 'GoogleMapsUri']
with open('summary.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(csv_header)
    writer.writerows(csv_data)

# %%
csvdata = pd.read_csv('summary.csv', dtype={"PostalCode": str})
csvdata
# Out:
#      Index                                Name                   DisplayName  \
# 0        0  places/ChIJj_kp38sLkkYRtVNMKdyoK50             Restaurant Pjazza
# 1        1  places/ChIJZaQV3ssLkkYRJ52yQx1DQL0             Restaurant Gaijin
# 2        2  places/ChIJDXicglMLkkYRXQ-rEXnUd8U       Boulevard Bar & Seafood
# 3        3  places/ChIJj3rD4csLkkYR4rtKxWnW3Gk    Ravintola Boulevard Social
# 4        4  places/ChIJ1SRMX8kLkkYROFfIICaTlEE                 Klaus K Hotel
# ..     ...                                 ...                           ...
# 322    322  places/ChIJ9-y5gTQKkkYRLA_QWXKFbug   Aleksanterinkadun Burger Oy
# 323    323  places/ChIJwYfK210LkkYRqTDU1ENfzOg                  Nanapo sushi
# 324    324  places/ChIJI48EeTQKkkYR6haLs4Waohg  Restaurant Konnichiwa Kamppi
# 325    325  places/ChIJXwYSWVIojkYRZQPO1tSJ9yQ                Cmb Ravintolat
# 326    326  places/ChIJN2tpV-ULkkYRH1Na7Rvjebc       Taco Bell Tennispalatsi
#
#     PostalCode                                      GoogleMapsUri
# 0        00120  https://maps.google.com/?cid=11325331351492383669
# 1        00120  https://maps.google.com/?cid=13636973464646753575
# 2        00120  https://maps.google.com/?cid=14229075164152926045
# 3        00120   https://maps.google.com/?cid=7628207618628697058
# 4        00120   https://maps.google.com/?cid=4725563700986533688
# ..         ...                                                ...
# 322      00100  https://maps.google.com/?cid=16748470790417026860
# 323      00100  https://maps.google.com/?cid=16774887456986378409
# 324      00100   https://maps.google.com/?cid=1775151102170961642
# 325      00100   https://maps.google.com/?cid=2663749251842835301
# 326      00100  https://maps.google.com/?cid=13220847890208543519
#
# [327 rows x 5 columns]

# %%
clean_data = csvdata.drop_duplicates(subset=["Name"]).reset_index(drop=True)
clean_data
# Out:
#      Index                                Name                    DisplayName  \
# 0        0  places/ChIJj_kp38sLkkYRtVNMKdyoK50              Restaurant Pjazza
# 1        1  places/ChIJZaQV3ssLkkYRJ52yQx1DQL0              Restaurant Gaijin
# 2        2  places/ChIJDXicglMLkkYRXQ-rEXnUd8U        Boulevard Bar & Seafood
# 3        3  places/ChIJj3rD4csLkkYR4rtKxWnW3Gk     Ravintola Boulevard Social
# 4        4  places/ChIJ1SRMX8kLkkYROFfIICaTlEE                  Klaus K Hotel
# ..     ...                                 ...                            ...
# 214    319  places/ChIJv5xGn5sLkkYRsWM1_o_50n4  Restaurant Pupu Tennispalatsi
# 215    320  places/ChIJl_KuX_YLkkYRfigtwXX1ueA  KotKot Helsinki Tennispalatsi
# 216    321  places/ChIJqaB9jjQLkkYRolhY7T_aHn4                    Hemingway's
# 217    322  places/ChIJ9-y5gTQKkkYRLA_QWXKFbug    Aleksanterinkadun Burger Oy
# 218    324  places/ChIJI48EeTQKkkYR6haLs4Waohg   Restaurant Konnichiwa Kamppi
#
#     PostalCode                                      GoogleMapsUri
# 0        00120  https://maps.google.com/?cid=11325331351492383669
# 1        00120  https://maps.google.com/?cid=13636973464646753575
# 2        00120  https://maps.google.com/?cid=14229075164152926045
# 3        00120   https://maps.google.com/?cid=7628207618628697058
# 4        00120   https://maps.google.com/?cid=4725563700986533688
# ..         ...                                                ...
# 214      00100   https://maps.google.com/?cid=9138640990728709041
# 215      00100  https://maps.google.com/?cid=16193243821288269950
# 216      00100   https://maps.google.com/?cid=9087941066180024482
# 217      00100  https://maps.google.com/?cid=16748470790417026860
# 218      00100   https://maps.google.com/?cid=1775151102170961642
#
# [219 rows x 5 columns]

# %%
clean_data.to_csv("../results/result.csv")
